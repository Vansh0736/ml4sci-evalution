# %%
"""
DeepLense Common Test I: Multi-Class Classification of Gravitational Lensing Signatures
Author: Vansh Jain
Organization: ML4SCI
"""

import os
import glob
import random
import logging
from typing import Tuple, List, Dict

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
from sklearn.metrics import roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Professional Logging Configuration
logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%H:%M:%S'
)

def set_seed(seed: int = 42) -> None:
    """
    Sets global seeds for reproducibility across Python, NumPy, and PyTorch.
    Ensures deterministic behavior in cuDNN backends.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    logging.info(f"Reproducibility seed set to: {seed}")

set_seed(42)
# Out:
# INFO: Reproducibility seed set to: 42

# %%
# Exploratory Data Analysis (EDA) & Verification 
# Define search pattern using the primary dataset directory
data_pattern = os.path.join("/kaggle/input/datasets/vanshdistsys2/common-task-dataset/dataset/train/no/*.npy")
sample_files = glob.glob(data_pattern)

if sample_files:
    # Extract a representative sample for dimensionality and flux verification
    sample_path = sample_files[0]
    sample_array = np.load(sample_path)
    
    logging.info(f"Data ingestion successful: {os.path.basename(sample_path)}")
    logging.info(f"Tensor Dimensionality: {sample_array.shape} | Precision: {sample_array.dtype}")
    logging.info(f"Radiometric Flux Range: [{sample_array.min():.4f}, {sample_array.max():.4f}]")
    
    # Visual validation of astrophysical signal
    plt.figure(figsize=(5, 5))
    # Standardizing array for 2D visualization
    render_target = np.squeeze(sample_array) if sample_array.ndim > 2 else sample_array
    
    plt.imshow(render_target, cmap='magma')
    plt.colorbar(label='Flux Intensity')
    plt.title(f"Representative Observation: {os.path.basename(sample_path)}\nGeometry: {sample_array.shape}")
    plt.axis('off')
    plt.tight_layout()
    plt.show()
else:
    logging.error(f"Integrity Check Failed: No .npy files discovered in {data_pattern}")
# Out:
# INFO: Data ingestion successful: 5955.npy
# INFO: Tensor Dimensionality: (1, 150, 150) | Precision: float64
# INFO: Radiometric Flux Range: [0.0000, 1.0000]

# %%
# Global Hyperparameter Configuration
CONFIG = {
    "seed": 42,
    "epochs": 100,              # Maximum training iterations (Early Stopping controlled)
    "learning_rate": 1e-4, 
    "weight_decay": 1e-4,       # L2 Regularization coefficient
    "batch_size": 32,
    "patience": 7,              # Early stopping epoch threshold
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    "classes": ["no", "sphere", "vort"],
    
    # Dataset Directory Mapping
    "train_dir": "/kaggle/input/datasets/vanshdistsys2/common-task-dataset/dataset/train",
    "val_dir": "/kaggle/input/datasets/vanshdistsys2/common-task-dataset/dataset/val"
}

logging.info(f"Execution Device: {CONFIG['device']}")
# Out:
# INFO: Execution Device: cuda

# %%
class DeepLenseDataset(Dataset):
    """
    Physically-constrained Dataset for parsing simulated lensing flux arrays.
    Implements stochastic spatial augmentations to enforce rotational invariance.
    """
    def __init__(self, file_paths: List[str], labels: List[int], is_train: bool = False):
        self.file_paths = file_paths
        self.labels = labels
        self.is_train = is_train

    def __len__(self) -> int:
        return len(self.file_paths)

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        # Load radiometric flux array [Expected input: (1, H, W)]
        img_array = np.load(self.file_paths[idx]).astype(np.float32)

        # Remove channel dimension for NumPy-based geometric transformations
        img_array = np.squeeze(img_array)

        # Stochastic Spatial Augmentation (Inference-safe)
        if self.is_train:
            # Random Horizontal/Vertical Flips
            if random.random() > 0.5:
                img_array = np.fliplr(img_array).copy()
            if random.random() > 0.5:
                img_array = np.flipud(img_array).copy()
            
            # Discrete 90-degree rotations to maintain pixel-grid alignment
            k = random.randint(0, 3)
            img_array = np.rot90(img_array, k=k).copy()

        # Restore channel dimension for PyTorch compatibility [1, H, W]
        img_array = np.expand_dims(img_array, axis=0)

        return torch.from_numpy(img_array), torch.tensor(self.labels[idx], dtype=torch.long)


def load_paths_and_labels(base_dir: str, classes: List[str]) -> Tuple[List[str], List[int]]:
    """Recursively crawls directory tree to map .npy file paths to class indices."""
    paths, labels = [], []
    for idx, cls_name in enumerate(classes):
        cls_dir = os.path.join(base_dir, cls_name)
        files = glob.glob(os.path.join(cls_dir, "*.npy"))
        paths.extend(files)
        labels.extend([idx] * len(files))
    return paths, labels


def prepare_dataloaders(config: Dict) -> Tuple[DataLoader, DataLoader]:
    """Initializes high-concurrency DataLoaders for train and validation splits."""
    train_paths, train_labels = load_paths_and_labels(config["train_dir"], config["classes"])
    val_paths, val_labels = load_paths_and_labels(config["val_dir"], config["classes"])

    if not train_paths or not val_paths:
        logging.error("Data pipeline failure: Verification of input directories failed.")
        return None, None

    train_set = DeepLenseDataset(train_paths, train_labels, is_train=True)
    val_set = DeepLenseDataset(val_paths, val_labels, is_train=False)

    train_loader = DataLoader(
        train_set, 
        batch_size=config["batch_size"], 
        shuffle=True,
        num_workers=2  # Utilizing multi-core loading for efficiency
    )
    val_loader = DataLoader(
        val_set, 
        batch_size=config["batch_size"], 
        shuffle=False
    )

    logging.info(f"Dataset Pipeline Initialized: {len(train_paths)} training, {len(val_paths)} validation samples.")
    return train_loader, val_loader

# Global Data Initialization
train_loader, val_loader = prepare_dataloaders(CONFIG)
# Out:
# INFO: Dataset Pipeline Initialized: 30000 training, 7500 validation samples.

# %%
class CustomPhysicsCNN(nn.Module):
    """
    Architectural Baseline: Shallow Convolutional Neural Network 
    tailored for hierarchical feature extraction from lensing simulations.
    
    Design incorporates Batch Normalization and Dropout (0.5) to mitigate
    overfitting and accelerate convergence on low-SNR astrophysical signals.
    """
    def __init__(self, num_classes: int = 3, input_channels: int = 1):
        super(CustomPhysicsCNN, self).__init__()
        
        # Feature Extraction Backbone
        self.features = nn.Sequential(
            # Block 1: Initial Edge Detection
            nn.Conv2d(input_channels, 16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),  
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            # Block 2: Intermediate Curvature Learning
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),  
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            # Block 3: High-level Structural Recognition
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64), 
            nn.ReLU(),
            nn.MaxPool2d(2, 2)
        )

        # Heuristic determination of flattened linear layer dimensions
        with torch.no_grad():
            dummy_input = torch.zeros(1, input_channels, 150, 150) 
            flatten_size = self.features(dummy_input).numel()

        # Classification Head with Regularization
        self.classifier = nn.Sequential(
            nn.Linear(flatten_size, 128),
            nn.BatchNorm1d(128), 
            nn.ReLU(),
            nn.Dropout(0.5), 
            nn.Linear(128, num_classes)
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """Propagates input through feature backbone and classification head."""
        x = self.features(x)
        x = torch.flatten(x, 1)
        return self.classifier(x)

# %%
import torchvision.models as models

def get_resnet18(num_classes: int = 3) -> nn.Module:
    """
    Standard ResNet-18 adapted for astrophysical domain-specific constraints.
    
    Modifications:
    1. Input layer reconfigured for single-channel (grayscale) flux maps.
    2. Classification head augmented with Dropout (0.5) to prevent 
       over-parameterized memorization of simulation artifacts.
    """
    # Initialize without pre-trained weights to learn physics-specific kernels
    model = models.resnet18(weights=None) 
    
    # Adaptation of the initial convolutional stem for 1-channel input
    model.conv1 = nn.Conv2d(
        in_channels=1, 
        out_channels=64, 
        kernel_size=7, 
        stride=2, 
        padding=3, 
        bias=False
    )
    
    # Reconfiguration of the Fully Connected (FC) head for multi-class classification
    num_ftrs = model.fc.in_features
    model.fc = nn.Sequential(
        nn.Dropout(p=0.5),
        nn.Linear(num_ftrs, num_classes)
    )
    
    return model

# %%
def train_model(model, train_loader, val_loader, config, model_name):
    """
    Core training pipeline with automated convergence monitoring.
    Implements ReduceLROnPlateau scheduling and state-dict checkpointing.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(
        model.parameters(), 
        lr=config["learning_rate"], 
        weight_decay=config.get("weight_decay", 1e-4)
    )
    # Scheduler adjusts learning rate based on validation loss stagnation
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=2, factor=0.5)
    
    model.to(config["device"])
    
    # Convergence Monitoring Parameters
    patience = config.get("patience", 7)
    trigger_times = 0
    best_val_loss = float('inf')
    save_path = f'best_{model_name}.pth'
    
    for epoch in range(config["epochs"]):
        # Phase 1: Training
        model.train()
        train_loss, train_correct, train_total = 0.0, 0, 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(config["device"]), labels.to(config["device"])
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

        # Phase 2: Validation (Inference)
        model.eval()
        val_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(config["device"]), labels.to(config["device"])
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        # Metric Normalization
        train_loss /= len(train_loader.dataset)
        val_loss /= len(val_loader.dataset)
        train_acc = 100. * train_correct / train_total
        val_acc = 100. * val_correct / val_total
        
        scheduler.step(val_loss)
        current_lr = optimizer.param_groups[0]['lr']

        logging.info(f"[{model_name}] Ep {epoch+1:02d} | Loss (T/V): {train_loss:.4f}/{val_loss:.4f} | Acc (T/V): {train_acc:.2f}%/{val_acc:.2f}% | LR: {current_lr:.6f}")

        # State-Dict Checkpointing & Early Stopping Logic
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            trigger_times = 0
            torch.save(model.state_dict(), save_path)
            logging.info(f"   --> Validation improvement. Optimized weights cached to {save_path}")
        else:
            trigger_times += 1
            if trigger_times >= patience:
                logging.info(f"Convergence threshold reached. Terminating at epoch {epoch+1}.")
                break

    # Restore global minimum state for final evaluation
    model.load_state_dict(torch.load(save_path))
    return model

# %%
#Custom CNN Execution
logging.info("Initializing phase: Custom CNN pipeline")
custom_cnn = CustomPhysicsCNN(num_classes=3, input_channels=1)


custom_cnn = train_model(custom_cnn, train_loader, val_loader, CONFIG, "Custom_CNN")

# ResNet-18 Execution
logging.info("Initializing phase: ResNet-18 baseline pipeline")
resnet_model = get_resnet18(num_classes=3)


resnet_model = train_model(resnet_model, train_loader, val_loader, CONFIG, "ResNet18")
# Out:
# INFO: Initializing phase: Custom CNN pipeline
# INFO: [Custom_CNN] Ep 01 | Loss (T/V): 1.1441/1.1002 | Acc (T/V): 34.34%/34.65% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 02 | Loss (T/V): 1.1184/1.0939 | Acc (T/V): 34.81%/36.16% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 03 | Loss (T/V): 1.1038/1.0892 | Acc (T/V): 36.40%/37.61% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 04 | Loss (T/V): 1.0909/1.0805 | Acc (T/V): 38.71%/37.31% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 05 | Loss (T/V): 1.0580/1.0416 | Acc (T/V): 42.66%/43.64% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 06 | Loss (T/V): 1.0030/0.9955 | Acc (T/V): 48.59%/49.40% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 07 | Loss (T/V): 0.9629/0.9511 | Acc (T/V): 51.82%/53.33% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 08 | Loss (T/V): 0.9313/0.9152 | Acc (T/V): 54.14%/55.63% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 12 | Loss (T/V): 0.8478/0.8393 | Acc (T/V): 60.09%/60.87% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 13 | Loss (T/V): 0.8315/0.8438 | Acc (T/V): 61.10%/60.09% | LR: 0.000100
# INFO: [Custom_CNN] Ep 14 | Loss (T/V): 0.8184/0.8002 | Acc (T/V): 61.71%/63.51% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 18 | Loss (T/V): 0.7644/0.8179 | Acc (T/V): 65.67%/62.55% | LR: 0.000100
# INFO: [Custom_CNN] Ep 19 | Loss (T/V): 0.7530/0.7550 | Acc (T/V): 66.10%/65.60% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 20 | Loss (T/V): 0.7426/0.8099 | Acc (T/V): 66.62%/61.16% | LR: 0.000100
# INFO: [Custom_CNN] Ep 21 | Loss (T/V): 0.7265/0.7380 | Acc (T/V): 66.97%/66.57% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 22 | Loss (T/V): 0.7238/0.7347 | Acc (T/V): 67.65%/65.87% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 23 | Loss (T/V): 0.7174/0.7740 | Acc (T/V): 68.06%/64.89% | LR: 0.000100
# INFO: [Custom_CNN] Ep 24 | Loss (T/V): 0.7055/0.7286 | Acc (T/V): 68.49%/67.51% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 25 | Loss (T/V): 0.6963/0.7064 | Acc (T/V): 69.06%/68.24% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 26 | Loss (T/V): 0.6899/0.7164 | Acc (T/V): 69.53%/67.72% | LR: 0.000100
# INFO: [Custom_CNN] Ep 27 | Loss (T/V): 0.6835/0.7543 | Acc (T/V): 70.06%/66.53% | LR: 0.000100
# INFO: [Custom_CNN] Ep 28 | Loss (T/V): 0.6746/0.9418 | Acc (T/V): 70.69%/57.40% | LR: 0.000050
# INFO: [Custom_CNN] Ep 32 | Loss (T/V): 0.6175/0.6372 | Acc (T/V): 73.36%/71.79% | LR: 0.000050
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 33 | Loss (T/V): 0.6073/0.6728 | Acc (T/V): 74.16%/70.04% | LR: 0.000050
# INFO: [Custom_CNN] Ep 34 | Loss (T/V): 0.6020/0.6453 | Acc (T/V): 74.31%/71.84% | LR: 0.000050
# INFO: [Custom_CNN] Ep 35 | Loss (T/V): 0.6046/0.6430 | Acc (T/V): 74.22%/71.96% | LR: 0.000025
# INFO: [Custom_CNN] Ep 36 | Loss (T/V): 0.5810/0.6232 | Acc (T/V): 75.42%/73.36% | LR: 0.000025
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 37 | Loss (T/V): 0.5747/0.6319 | Acc (T/V): 76.09%/72.64% | LR: 0.000025
# INFO: [Custom_CNN] Ep 38 | Loss (T/V): 0.5725/0.5984 | Acc (T/V): 75.87%/74.41% | LR: 0.000025
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 39 | Loss (T/V): 0.5669/0.6054 | Acc (T/V): 76.11%/74.20% | LR: 0.000025
# INFO: [Custom_CNN] Ep 40 | Loss (T/V): 0.5599/0.6006 | Acc (T/V): 76.86%/74.05% | LR: 0.000025
# INFO: [Custom_CNN] Ep 41 | Loss (T/V): 0.5586/0.5991 | Acc (T/V): 76.65%/74.25% | LR: 0.000013
# INFO: [Custom_CNN] Ep 42 | Loss (T/V): 0.5470/0.5963 | Acc (T/V): 77.35%/74.83% | LR: 0.000013
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 43 | Loss (T/V): 0.5409/0.6088 | Acc (T/V): 77.30%/74.05% | LR: 0.000013
# INFO: [Custom_CNN] Ep 44 | Loss (T/V): 0.5446/0.6008 | Acc (T/V): 77.40%/74.29% | LR: 0.000013
# INFO: [Custom_CNN] Ep 45 | Loss (T/V): 0.5411/0.5957 | Acc (T/V): 77.63%/75.15% | LR: 0.000013
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 46 | Loss (T/V): 0.5417/0.5897 | Acc (T/V): 77.57%/75.12% | LR: 0.000013
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 47 | Loss (T/V): 0.5388/0.5920 | Acc (T/V): 77.66%/74.76% | LR: 0.000013
# INFO: [Custom_CNN] Ep 48 | Loss (T/V): 0.5361/0.5902 | Acc (T/V): 77.79%/74.79% | LR: 0.000013
# INFO: [Custom_CNN] Ep 52 | Loss (T/V): 0.5281/0.5885 | Acc (T/V): 78.06%/75.24% | LR: 0.000006
# INFO: [Custom_CNN] Ep 53 | Loss (T/V): 0.5235/0.5840 | Acc (T/V): 78.45%/75.35% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 54 | Loss (T/V): 0.5180/0.5823 | Acc (T/V): 78.57%/75.37% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 55 | Loss (T/V): 0.5176/0.5820 | Acc (T/V): 78.62%/75.32% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 56 | Loss (T/V): 0.5162/0.5817 | Acc (T/V): 78.59%/75.61% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 57 | Loss (T/V): 0.5165/0.5841 | Acc (T/V): 78.71%/75.11% | LR: 0.000006
# INFO: [Custom_CNN] Ep 58 | Loss (T/V): 0.5172/0.5833 | Acc (T/V): 78.88%/75.29% | LR: 0.000006
# INFO: [Custom_CNN] Ep 59 | Loss (T/V): 0.5165/0.6021 | Acc (T/V): 78.71%/74.35% | LR: 0.000003
# INFO: [Custom_CNN] Ep 60 | Loss (T/V): 0.5183/0.5819 | Acc (T/V): 78.71%/75.48% | LR: 0.000003
# INFO: [Custom_CNN] Ep 61 | Loss (T/V): 0.5158/0.5797 | Acc (T/V): 78.83%/75.44% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 62 | Loss (T/V): 0.5123/0.5827 | Acc (T/V): 78.86%/75.35% | LR: 0.000003
# INFO: [Custom_CNN] Ep 63 | Loss (T/V): 0.5072/0.5794 | Acc (T/V): 79.03%/75.75% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 64 | Loss (T/V): 0.5147/0.5865 | Acc (T/V): 78.89%/75.17% | LR: 0.000003
# INFO: [Custom_CNN] Ep 68 | Loss (T/V): 0.5122/0.5792 | Acc (T/V): 79.01%/75.35% | LR: 0.000002
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 69 | Loss (T/V): 0.5168/0.5818 | Acc (T/V): 78.93%/75.53% | LR: 0.000002
# INFO: [Custom_CNN] Ep 70 | Loss (T/V): 0.5123/0.5765 | Acc (T/V): 79.22%/75.83% | LR: 0.000002
# INFO:    --> Validation improvement. Optimized weights cached to best_Custom_CNN.pth
# INFO: [Custom_CNN] Ep 71 | Loss (T/V): 0.5083/0.5789 | Acc (T/V): 79.17%/75.64% | LR: 0.000002
# INFO: [Custom_CNN] Ep 72 | Loss (T/V): 0.5080/0.5785 | Acc (T/V): 79.26%/75.55% | LR: 0.000002
# INFO: [Custom_CNN] Ep 73 | Loss (T/V): 0.5080/0.5796 | Acc (T/V): 79.25%/75.69% | LR: 0.000001
# INFO: [Custom_CNN] Ep 74 | Loss (T/V): 0.5127/0.5802 | Acc (T/V): 78.68%/75.69% | LR: 0.000001
# INFO: [Custom_CNN] Ep 75 | Loss (T/V): 0.5035/0.5846 | Acc (T/V): 79.53%/75.24% | LR: 0.000001
# INFO: [Custom_CNN] Ep 76 | Loss (T/V): 0.4994/0.5884 | Acc (T/V): 79.59%/75.08% | LR: 0.000000
# INFO: [Custom_CNN] Ep 77 | Loss (T/V): 0.5078/0.5813 | Acc (T/V): 79.31%/75.48% | LR: 0.000000
# INFO: Convergence threshold reached. Terminating at epoch 77.
# INFO: Initializing phase: ResNet-18 baseline pipeline
# INFO: [ResNet18] Ep 01 | Loss (T/V): 1.1496/1.1012 | Acc (T/V): 33.47%/35.03% | LR: 0.000100
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 02 | Loss (T/V): 1.1175/1.1015 | Acc (T/V): 34.04%/34.19% | LR: 0.000100
# INFO: [ResNet18] Ep 03 | Loss (T/V): 1.1088/1.1774 | Acc (T/V): 34.04%/33.33% | LR: 0.000100
# INFO: [ResNet18] Ep 04 | Loss (T/V): 1.0944/2.5533 | Acc (T/V): 36.98%/33.33% | LR: 0.000050
# INFO: [ResNet18] Ep 05 | Loss (T/V): 1.0433/1.1069 | Acc (T/V): 43.24%/40.69% | LR: 0.000050
# INFO: [ResNet18] Ep 06 | Loss (T/V): 1.0039/2.6917 | Acc (T/V): 47.25%/33.28% | LR: 0.000050
# INFO: [ResNet18] Ep 07 | Loss (T/V): 0.9690/1.0985 | Acc (T/V): 50.71%/43.21% | LR: 0.000050
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 08 | Loss (T/V): 0.9384/0.9581 | Acc (T/V): 53.24%/51.76% | LR: 0.000050
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 09 | Loss (T/V): 0.9051/1.0669 | Acc (T/V): 55.52%/47.88% | LR: 0.000050
# INFO: [ResNet18] Ep 10 | Loss (T/V): 0.8833/0.8999 | Acc (T/V): 56.93%/55.63% | LR: 0.000050
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 11 | Loss (T/V): 0.8595/1.9014 | Acc (T/V): 58.63%/39.60% | LR: 0.000050
# INFO: [ResNet18] Ep 12 | Loss (T/V): 0.8352/2.6960 | Acc (T/V): 59.92%/36.63% | LR: 0.000050
# INFO: [ResNet18] Ep 13 | Loss (T/V): 0.8197/1.2841 | Acc (T/V): 60.98%/45.15% | LR: 0.000025
# INFO: [ResNet18] Ep 14 | Loss (T/V): 0.7624/0.7470 | Acc (T/V): 64.65%/66.01% | LR: 0.000025
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 15 | Loss (T/V): 0.7427/0.8054 | Acc (T/V): 65.31%/62.21% | LR: 0.000025
# INFO: [ResNet18] Ep 16 | Loss (T/V): 0.7248/0.7680 | Acc (T/V): 66.69%/63.31% | LR: 0.000025
# INFO: [ResNet18] Ep 17 | Loss (T/V): 0.7148/0.8740 | Acc (T/V): 67.29%/57.60% | LR: 0.000013
# INFO: [ResNet18] Ep 18 | Loss (T/V): 0.6781/0.6705 | Acc (T/V): 69.46%/69.81% | LR: 0.000013
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 19 | Loss (T/V): 0.6602/0.6706 | Acc (T/V): 70.16%/69.20% | LR: 0.000013
# INFO: [ResNet18] Ep 20 | Loss (T/V): 0.6514/0.6781 | Acc (T/V): 70.72%/69.41% | LR: 0.000013
# INFO: [ResNet18] Ep 21 | Loss (T/V): 0.6348/0.7629 | Acc (T/V): 71.75%/64.40% | LR: 0.000006
# INFO: [ResNet18] Ep 22 | Loss (T/V): 0.6192/0.6533 | Acc (T/V): 72.85%/70.01% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 23 | Loss (T/V): 0.6135/0.6294 | Acc (T/V): 72.71%/71.97% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 24 | Loss (T/V): 0.6041/0.6263 | Acc (T/V): 73.32%/72.08% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 25 | Loss (T/V): 0.5949/0.6276 | Acc (T/V): 73.77%/71.83% | LR: 0.000006
# INFO: [ResNet18] Ep 26 | Loss (T/V): 0.5935/0.6153 | Acc (T/V): 73.93%/72.37% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 27 | Loss (T/V): 0.5886/0.6188 | Acc (T/V): 74.16%/71.84% | LR: 0.000006
# INFO: [ResNet18] Ep 28 | Loss (T/V): 0.5838/0.6145 | Acc (T/V): 74.20%/72.01% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 29 | Loss (T/V): 0.5775/0.6141 | Acc (T/V): 74.81%/72.67% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 30 | Loss (T/V): 0.5719/0.6107 | Acc (T/V): 75.06%/72.57% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 31 | Loss (T/V): 0.5659/0.6059 | Acc (T/V): 75.36%/73.01% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 32 | Loss (T/V): 0.5610/0.6087 | Acc (T/V): 75.53%/72.95% | LR: 0.000006
# INFO: [ResNet18] Ep 33 | Loss (T/V): 0.5570/0.5873 | Acc (T/V): 75.63%/74.00% | LR: 0.000006
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 34 | Loss (T/V): 0.5504/0.6151 | Acc (T/V): 76.00%/72.89% | LR: 0.000006
# INFO: [ResNet18] Ep 35 | Loss (T/V): 0.5503/0.6095 | Acc (T/V): 76.01%/72.73% | LR: 0.000006
# INFO: [ResNet18] Ep 36 | Loss (T/V): 0.5451/0.6083 | Acc (T/V): 76.36%/73.04% | LR: 0.000003
# INFO: [ResNet18] Ep 37 | Loss (T/V): 0.5279/0.6342 | Acc (T/V): 77.38%/72.59% | LR: 0.000003
# INFO: [ResNet18] Ep 38 | Loss (T/V): 0.5254/0.5934 | Acc (T/V): 77.29%/74.01% | LR: 0.000003
# INFO: [ResNet18] Ep 39 | Loss (T/V): 0.5224/0.5791 | Acc (T/V): 77.60%/74.80% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 40 | Loss (T/V): 0.5215/0.5839 | Acc (T/V): 77.61%/74.31% | LR: 0.000003
# INFO: [ResNet18] Ep 41 | Loss (T/V): 0.5207/0.6328 | Acc (T/V): 77.56%/72.37% | LR: 0.000003
# INFO: [ResNet18] Ep 42 | Loss (T/V): 0.5090/0.5698 | Acc (T/V): 78.33%/75.52% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 43 | Loss (T/V): 0.5115/0.5705 | Acc (T/V): 78.27%/75.12% | LR: 0.000003
# INFO: [ResNet18] Ep 44 | Loss (T/V): 0.5020/0.5858 | Acc (T/V): 78.28%/74.55% | LR: 0.000003
# INFO: [ResNet18] Ep 45 | Loss (T/V): 0.5067/0.5648 | Acc (T/V): 78.36%/75.32% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 46 | Loss (T/V): 0.5044/0.5610 | Acc (T/V): 78.50%/75.37% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 47 | Loss (T/V): 0.5036/0.5754 | Acc (T/V): 78.51%/75.31% | LR: 0.000003
# INFO: [ResNet18] Ep 48 | Loss (T/V): 0.4980/0.5516 | Acc (T/V): 79.16%/75.49% | LR: 0.000003
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 49 | Loss (T/V): 0.4940/0.5598 | Acc (T/V): 78.78%/75.92% | LR: 0.000003
# INFO: [ResNet18] Ep 50 | Loss (T/V): 0.4964/0.5520 | Acc (T/V): 78.88%/75.72% | LR: 0.000003
# INFO: [ResNet18] Ep 51 | Loss (T/V): 0.4925/0.5565 | Acc (T/V): 79.21%/75.80% | LR: 0.000002
# INFO: [ResNet18] Ep 52 | Loss (T/V): 0.4815/0.5597 | Acc (T/V): 79.88%/75.32% | LR: 0.000002
# INFO: [ResNet18] Ep 53 | Loss (T/V): 0.4852/0.5507 | Acc (T/V): 79.45%/76.21% | LR: 0.000002
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 54 | Loss (T/V): 0.4793/0.5570 | Acc (T/V): 79.71%/76.08% | LR: 0.000002
# INFO: [ResNet18] Ep 55 | Loss (T/V): 0.4800/0.5556 | Acc (T/V): 79.69%/76.08% | LR: 0.000002
# INFO: [ResNet18] Ep 56 | Loss (T/V): 0.4802/0.5583 | Acc (T/V): 79.75%/75.96% | LR: 0.000001
# INFO: [ResNet18] Ep 57 | Loss (T/V): 0.4718/0.5441 | Acc (T/V): 80.05%/76.40% | LR: 0.000001
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 58 | Loss (T/V): 0.4712/0.5470 | Acc (T/V): 80.20%/76.61% | LR: 0.000001
# INFO: [ResNet18] Ep 59 | Loss (T/V): 0.4701/0.5442 | Acc (T/V): 80.07%/76.48% | LR: 0.000001
# INFO: [ResNet18] Ep 60 | Loss (T/V): 0.4676/0.5488 | Acc (T/V): 80.35%/76.45% | LR: 0.000000
# INFO: [ResNet18] Ep 61 | Loss (T/V): 0.4686/0.5482 | Acc (T/V): 80.38%/76.33% | LR: 0.000000
# INFO: [ResNet18] Ep 62 | Loss (T/V): 0.4691/0.5439 | Acc (T/V): 80.19%/76.72% | LR: 0.000000
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 63 | Loss (T/V): 0.4658/0.5534 | Acc (T/V): 80.46%/76.09% | LR: 0.000000
# INFO: [ResNet18] Ep 64 | Loss (T/V): 0.4632/0.5430 | Acc (T/V): 80.45%/76.61% | LR: 0.000000
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 65 | Loss (T/V): 0.4652/0.5485 | Acc (T/V): 80.42%/76.59% | LR: 0.000000
# INFO: [ResNet18] Ep 66 | Loss (T/V): 0.4663/0.5403 | Acc (T/V): 80.33%/76.49% | LR: 0.000000
# INFO:    --> Validation improvement. Optimized weights cached to best_ResNet18.pth
# INFO: [ResNet18] Ep 67 | Loss (T/V): 0.4641/0.5407 | Acc (T/V): 80.44%/76.68% | LR: 0.000000
# INFO: [ResNet18] Ep 68 | Loss (T/V): 0.4633/0.5484 | Acc (T/V): 80.40%/76.43% | LR: 0.000000
# INFO: [ResNet18] Ep 69 | Loss (T/V): 0.4640/0.5413 | Acc (T/V): 80.55%/76.63% | LR: 0.000000
# INFO: [ResNet18] Ep 70 | Loss (T/V): 0.4659/0.5413 | Acc (T/V): 80.41%/76.93% | LR: 0.000000
# INFO: [ResNet18] Ep 71 | Loss (T/V): 0.4641/0.5485 | Acc (T/V): 80.43%/76.77% | LR: 0.000000
# INFO: [ResNet18] Ep 72 | Loss (T/V): 0.4657/0.5411 | Acc (T/V): 80.47%/76.95% | LR: 0.000000
# INFO: [ResNet18] Ep 73 | Loss (T/V): 0.4556/0.5411 | Acc (T/V): 80.75%/76.79% | LR: 0.000000
# INFO: Convergence threshold reached. Terminating at epoch 73.

# %%
def get_predictions(model, loader, device):
    model.eval()
    all_probs = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            # Use Softmax to get probabilities for the ROC curve
            probs = torch.softmax(outputs, dim=1)
            all_probs.append(probs.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
    return np.concatenate(all_labels), np.concatenate(all_probs)

# Collect data for the plots
labels_val, probs_custom = get_predictions(custom_cnn, val_loader, CONFIG["device"])
_, probs_resnet = get_predictions(resnet_model, val_loader, CONFIG["device"])

# %%
def plot_comparative_roc(y_true: np.ndarray, probs_dict: Dict[str, np.ndarray]) -> None:
    """
    Computes and visualizes the Macro-average Receiver Operating Characteristic (ROC) 
    curves to evaluate the discriminative performance of the candidate architectures.
    """
    # Setting a clean, publication-standard style
    plt.style.use('seaborn-v0_8-muted')
    plt.figure(figsize=(9, 7))
    
    # One-vs-Rest (OvR) binarization for multi-class metrics
    y_bin = label_binarize(y_true, classes=[0, 1, 2])
    n_classes = y_bin.shape[1]
    
    # Publication-quality color mapping
    colors = {'Custom_CNN': '#2c7fb8', 'ResNet18': '#d95f02'}
    linestyles = {'Custom_CNN': '-', 'ResNet18': '--'}
    
    for model_name, probs in probs_dict.items():
        fpr, tpr = {}, {}
        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], probs[:, i])
            
        # Compute Macro-average ROC curve
        all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(n_classes):
            mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
            
        mean_tpr /= n_classes
        macro_auc = auc(all_fpr, mean_tpr)
        
        plt.plot(all_fpr, mean_tpr, 
                 label=f'{model_name} (Macro-AUC: {macro_auc:.3f})',
                 color=colors.get(model_name, 'black'), 
                 linestyle=linestyles.get(model_name, '-'), 
                 linewidth=2.2)

    # Reference baseline (Random Chance)
    plt.plot([0, 1], [0, 1], color='gray', linestyle=':', lw=1.2)
    
    # Axes and Labeling
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)', fontsize=12)
    plt.ylabel('True Positive Rate (TPR)', fontsize=12)
    plt.title('Performance Benchmark: Architectural ROC Comparison', fontsize=14, fontweight='bold')
    plt.legend(loc="lower right", frameon=True)
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

# ---

# %%
plot_comparative_roc(labels_val, {
    'Custom_CNN': probs_custom,
    'ResNet18': probs_resnet
})
